# %% [markdown]
# <a href="https://colab.research.google.com/github/Storm00212/Data-manipulation-using-python/blob/main/Reading_datasets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2544c24b-08a5-4102-b90e-7109ee3a6c58" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2544c24b-08a5-4102-b90e-7109ee3a6c58">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df1 = pd.read_csv('poultry_health_dataset.csv')


df1.head()
# Out:
#   animal_type  age_months  body_temperature_c  feed_intake_kg  water_intake_l  \
# 0     poultry         122               37.46            2.16           26.88
# 1     poultry          84               38.63            2.84           12.98
# 2     poultry         190               38.49            5.46           20.45
# 3     poultry          54               40.05            5.17           55.62
# 4     poultry         223               37.89           12.21           72.45
#
#    milk_production_l       season vaccination_status disease_diagnosis
# 0                0.0          dry               none      malnutrition
# 1                0.0          dry               full      malnutrition
# 2                0.0   long_rains            partial           healthy
# 3                0.0  short_rains               none             fever
# 4                0.0          dry               none           healthy

# %%
df1 = df1.drop(columns=['milk_production_l'])
display(df1.head())
# Out:
#   animal_type  age_months  body_temperature_c  feed_intake_kg  water_intake_l  \
# 0     poultry         122               37.46            2.16           26.88
# 1     poultry          84               38.63            2.84           12.98
# 2     poultry         190               38.49            5.46           20.45
# 3     poultry          54               40.05            5.17           55.62
# 4     poultry         223               37.89           12.21           72.45
#
#         season vaccination_status disease_diagnosis
# 0          dry               none      malnutrition
# 1          dry               full      malnutrition
# 2   long_rains            partial           healthy
# 3  short_rains               none             fever
# 4          dry               none           healthy

# %%
uploaded2 = files.upload()
# Out:
#      <input type="file" id="files-d42be20a-a214-4ae3-b0a2-e7bc3fd8f114" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d42be20a-a214-4ae3-b0a2-e7bc3fd8f114">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
