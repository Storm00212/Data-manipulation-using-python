# %% [markdown]
# <a href="https://colab.research.google.com/github/Storm00212/Data-manipulation-using-python/blob/main/Central_limit_theorem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# For reproducibility
np.random.seed(42)

# 1.  non-normal population
population = np.random.uniform(low=0, high=10, size=100000)

# %%
# 2. Parameters
sample_sizes = [1, 5, 30]
num_samples = 10000
